# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaEG/ResearchQ2/blob/main/Copy_of_Python_Notebook_Setup_by_Daniela_Enciso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # 2: Is there an association between trouble falling asleep and the amount of fast food eaten in the past seven days?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1
# ![Screenshot 2023-04-30 at 10.51.52 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['H4SP5'].value_counts()
# Out:
# 0    2400
#      1390
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: H4SP5, dtype: int64

# %%
df['Trouble_Sleeping']= df['H4SP5']
df['Trouble_Sleeping'].value_counts()
# Out:
# 0    2400
#      1390
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: Trouble_Sleeping, dtype: int64

# %%
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].loc[ df['Trouble_Sleeping'] !=' ']
df['Trouble_Sleeping'].value_counts()
# Out:
# 0    2400
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: Trouble_Sleeping, dtype: int64

# %%
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].loc[ df['Trouble_Sleeping'] !='5']
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].loc[ df['Trouble_Sleeping'] !='8']
df['Trouble_Sleeping'].value_counts()
# Out:
# 0    2400
# 1     950
# 2     911
# 4     411
# 3     395
# Name: Trouble_Sleeping, dtype: int64

# %%
df['Trouble_Sleeping'].replace(['0','1','2','4','3'], ['NEVER','LESS THAN ONCE','ONE OR TWO','FIVE OR MORE','THREE OR FOUR'] , inplace= True)
df['Trouble_Sleeping'].value_counts()
# Out:
# NEVER             2400
# LESS THAN ONCE     950
# ONE OR TWO         911
# FIVE OR MORE       411
# THREE OR FOUR      395
# Name: Trouble_Sleeping, dtype: int64

# %%
pip install researchPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
rp.summary_cat(df['Trouble_Sleeping'])
# Out:
#            Variable         Outcome  Count  Percent
# 0  Trouble_Sleeping           NEVER   2400    47.37
# 1                    LESS THAN ONCE    950    18.75
# 2                        ONE OR TWO    911    17.98
# 3                      FIVE OR MORE    411     8.11
# 4                     THREE OR FOUR    395     7.80

# %%
#Graphs and tables or statistics

# %%
df['H4SP5'].value_counts()
# Out:
# 0    2400
#      1390
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: H4SP5, dtype: int64

# %%
df['Trouble_Sleeping'] = df['H4SP5']

# %%
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].loc[ df['Trouble_Sleeping'] !=' ']
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].loc[ df['Trouble_Sleeping'] !='5']
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].loc[ df['Trouble_Sleeping'] !='8']
df['Trouble_Sleeping'].value_counts()
# Out:
# 0    2400
# 1     950
# 2     911
# 4     411
# 3     395
# Name: Trouble_Sleeping, dtype: int64

# %%
df['Trouble_Sleeping'].replace(['0','1','2','3','4'] , ['Never', 'Less Than Once', 'One or Two','Three or Four','Five or More'], inplace = True)
df['Trouble_Sleeping'].value_counts()
# Out:
# Never             2400
# Less Than Once     950
# One or Two         911
# Five or More       411
# Three or Four      395
# Name: Trouble_Sleeping, dtype: int64

# %%
df['Trouble_Sleeping'].value_counts().plot(kind ='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Trouble_Sleeping'>

# %%
plt.xlabel("Amount Trouble Sleeping")
plt.ylabel("Percent")
plt.title("How often did you have trouble falling asleep?")
df['Trouble_Sleeping'].value_counts(normalize = True).plot(kind ='barh', color = 'red', width = 0.2, alpha = 0.5)
# Out:
# <Axes: title={'center': 'How often did you have trouble falling asleep?'}, ylabel='Percent'>

# %% [markdown]
# Codebook 2:
# ![Screenshot 2023-04-30 at 11.03.08 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['H4GH8'].dtype
# Out:
# dtype('O')

# %%
df['Fast_Food_Eaten'] = df['H4GH8']
df['Fast_Food_Eaten'].dtype
# Out:
# dtype('O')

# %%
df['Fast_Food_Eaten'] = pd.to_numeric(df['Fast_Food_Eaten'] , errors='coerce')
df['Fast_Food_Eaten'].dtype
# Out:
# dtype('float64')

# %%
df['Fast_Food_Eaten'] = df['Fast_Food_Eaten'].loc[ df['Fast_Food_Eaten'] < 99]
df['Fast_Food_Eaten'].max()
# Out:
# 35.0

# %%
df['Fast_Food_Eaten'].mean()
# Out:
# 2.3379948788654716

# %%
rp.summary_cont(df['Fast_Food_Eaten'])
# Out:
#           Variable       N   Mean     SD    SE  95% Conf.  Interval
# 0  Fast_Food_Eaten  5077.0  2.338  2.849  0.04     2.2596    2.4164

# %%
rp.summarize(df['Fast_Food_Eaten'])
# Out:
#               Name     N   Mean Median Variance     SD    SE  \
# 0  Fast_Food_Eaten  5077  2.338    2.0   8.1166  2.849  0.04
#
#   95% Conf. Interval
# 0   [2.2596, 2.4164]

# %%
df['Fast_Food_Eaten'].describe()
# Out:
# count    5077.000000
# mean        2.337995
# std         2.848970
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        35.000000
# Name: Fast_Food_Eaten, dtype: float64

# %%
#Graphs and tables or statistics

# %%
sns.histplot( x = 'Fast_Food_Eaten' , data=df, bins = 10, kde = True)
# Out:
# <Axes: xlabel='Fast_Food_Eaten', ylabel='Count'>

# %%
sns.boxplot(x = 'Fast_Food_Eaten' , data=df)
# Out:
# <Axes: xlabel='Fast_Food_Eaten'>
